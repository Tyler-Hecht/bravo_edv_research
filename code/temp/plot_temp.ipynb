# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
INPUT_FILE = "../../data/temp/regional_temp_data.csv"
OUTPUT_FILE = "../../plots/other/temp_plot.png"

# %%
df = pd.read_csv(INPUT_FILE, index_col = 0)
df.index = pd.to_datetime(df.index)
df
# Out:
#              Region 1   Region 2   Region 3   Region 4   Region 5   Region 6  \
# 2018-01-01 -15.837069 -10.347318  -7.526191   0.256565 -15.160282  -0.363642
# 2018-01-02 -12.189956  -5.388370  -5.612809   1.883143 -10.613858   1.298075
# 2018-01-03  -5.170511  -3.484295  -2.236547   4.067688  -9.743023   9.192431
# 2018-01-04  -4.535368  -5.003550  -4.980320   2.645091 -12.728201  10.064703
# 2018-01-05  -6.707461 -11.330217  -9.039630   4.140429 -13.790228  13.971358
# ...               ...        ...        ...        ...        ...        ...
# 2025-12-27  -7.143334  -2.834758   7.618850  22.917213   5.218045  24.682628
# 2025-12-28  -0.999950   3.444298  10.161617  21.810269   8.003743  21.329236
# 2025-12-29   3.223324   7.403524  13.728554  16.874758  -3.850697   8.679618
# 2025-12-30  -2.502194  -3.746495  -1.767334   6.743017  -3.643315  12.168838
# 2025-12-31  -5.076217  -1.883897   1.412966  11.654014  -1.484326  17.616059
#
#              Region 7  Region 8   Region 9  Region 10
# 2018-01-01 -13.126441 -9.710529  15.798783  -6.738495
# 2018-01-02  -4.330759 -1.674502  14.343217  -4.513651
# 2018-01-03  -1.263505 -1.196697  14.299780  -4.316342
# 2018-01-04  -1.880859 -0.142819  15.886730  -5.315687
# 2018-01-05  -2.651693  0.232164  16.154701  -5.215090
# ...               ...       ...        ...        ...
# 2025-12-27  16.362055  5.967286   9.848556 -17.823341
# 2025-12-28  11.046786 -5.287031   9.045837 -18.548098
# 2025-12-29  -2.133836  0.504085  10.344066 -16.120822
# 2025-12-30   7.988128  5.614722  10.514403 -15.098077
# 2025-12-31  12.794016  6.337283   9.486295 -15.284951
#
# [2922 rows x 10 columns]

# %%
fig, axs = plt.subplots(2, 5)
fig.set_figwidth(15)
fig.subplots_adjust(top=0.85)
plt.subplots_adjust(hspace=0.6)
for region in range(1, 11):
    i = (region-1) // 5
    j = (region-1) % 5
    axs[i, j].title.set_text(f"Region {region}")
    axs[i, j].plot(df.index, df[f"Region {region}"], linewidth = 0.75)
    axs[i, j].tick_params(axis = "x", labelrotation=45)
    axs[i, j].set_ylim(-25, 45)
    # if j != 0:
    #     axs[i, j].tick_params(labelleft = False)
fig.suptitle("Temperature (°C)", fontsize = 16)
fig.tight_layout()
fig.savefig(OUTPUT_FILE, dpi = 500)
